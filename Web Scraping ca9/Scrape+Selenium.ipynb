# %% [markdown]
# chromedriver download: https://chromedriver.chromium.org/downloads (match to you chrome version)

# %%
from bs4 import BeautifulSoup
import requests
import re
import numpy as np
import pandas as pd
from selenium import webdriver

# %%
def web_scrape_page():
    
    url = driver.current_url

    resp = requests.get(url)
    
    # All info from webpage scraped
    soup = BeautifulSoup(resp.text,'html.parser')
    
    # Scrape coa_dg_table table for all string elements
    data = []
    table = soup.find('table', attrs={'class':'coa_dg_table'})
    table_body = table.find('tbody')

    rows = table_body.find_all('tr')
    for row in rows:
        cols = row.find_all('td')
        cols = [ele.text.strip() for ele in cols]
        data.append([ele for ele in cols if ele]) # Get rid of empty values
        
    final_df = pd.DataFrame(data)
    final_df = final_df.rename(columns={0: "Case Name", 
                                        1: "Case No.",
                                        2: "Case Panel",
                                        3: "Hearing Location",
                                        4: "Hearing Date",
                                        5: "Audio",
                                        6: "Video"})
    
    # Scrape coa_dg_table table for links to audio and video files
    audio = []
    video = []

    for a in table_body.find_all('a', href=True):
        if 'video' in a['href']:
            video.append(a['href'])
        else:
            audio.append(a['href'])
    
    # Add parent website to beinning of string
    audio = ['https://www.ca9.uscourts.gov/media/' + x for x in audio]
    video = ['https://www.ca9.uscourts.gov/media/' + x for x in video]
    
    # Append to final dataframe
    final_df['Audio'] = audio
    final_df['Video'] = video
    
    
    return final_df

# %% [markdown]
# Run the following to download the correct chromedriver

# %%
# !pip install seleniumbase

# %%
# !seleniumbase install chromedriver latest

# %% [markdown]
# Take path out (ex: '/anaconda3/lib/python3.7/site-packages/seleniumbase/drivers/chromedriver') and replace line 14 below. If still doesnt work let me know.

# %%
from selenium.common.exceptions import NoSuchElementException
import time

#Initializing pg DataFrame that will eventually contain all scraped information
pg = pd.DataFrame()

#Using selenium's webdriver to create basic Chrome Options when opening browser
options = webdriver.ChromeOptions()
options.add_argument('--ignore-certificate-errors')
options.add_argument("--test-type")

#Using selenium's webdriver to open Google Chrome with stated options 
#Goes directly to url which is the first page of IMDB Top 250 list  
driver = webdriver.Chrome('/anaconda3/lib/python3.7/site-packages/seleniumbase/drivers/chromedriver', options = options)
driver.get("https://www.ca9.uscourts.gov/media/")

#Scrape page until there isn't a 'Next »' button
#Merge previous pages (pg) to current page (pg_current) until no pages are remaining
pages_remaining = True

while pages_remaining == True:

    pg_current = web_scrape_page()
    pg = pd.concat([pg,pg_current])

    try:
        next_link = driver.find_element_by_link_text(">>") 
        next_link.click()
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(5)

    except NoSuchElementException:
        pages_remaining = False

#Close browser
driver.close()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-13-c0e95e50154d> in <module>
#      27         next_link = driver.find_element_by_link_text(">>")
#      28         next_link.click()
# ---> 29         driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#      30         time.sleep(5)
#      31
#
# //anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# //anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# //anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=85.0.4183.121)

# %%
pg
# Out:
#                                             Case Name  Case No.  \
# 0                        Jenny Flores v. William Barr  20-55951
# 1    Gary Romanchuk v. SCUF & CWUF Joint Benefit Fund  17-56069
# 2                            USA v. Justin Nekeferoff  19-30015
# 3                George Young, Jr. v. State of Hawaii  12-17808
# 4               Maria Medina Tovar v. Laura Zuchowski  18-35072
# 5                                  Jorge Rojas v. FAA  17-55036
# 6           Harvest Rock Church, Inc. v. Gavin Newsom  20-55907
# 7                               USA v. Isaac Bautista  19-10448
# 8                  Alice Brown v. County of Del Norte  18-16689
# 9                    Jeffrey Green v. City of Phoenix  19-16682
# 10          Yes on Prop. B v. City and County of S.F.  20-15456
# 11                     Alex Hernandez v. William Barr  17-73332
# 12                               Dan Jackson v. ONHIR  18-17247
# 13  Index Newspapers LLC v. United States Marshals...  20-35739
# 14                                        In re: Hamm   20-1049
# 15                                   In re: Berkovich   20-1025
# 16                                      In re: Rivera   20-1024
# 17                                     In re: SIENEGA   19-1334
# 18                  Kimetra Brice v. Plain Green, LLC  19-15707
# 19                       Kevin Cooper v. Gavin Newsom  18-16547
# 20                           Borey Ai v. William Barr  18-70032
# 21            Israel Alvarado-Herrera v. William Barr  18-70191
# 22                    Service Employees Intl. v. NLRB  19-70334
# 23                            Eli Attia v. Google LLC  19-15771
# 24               180 Land Co LLC v. City of Las Vegas  19-16114
# 25             Suzanne Stone v. UnitedHealthcare Ins.  19-16227
# 26                      Murray Hooper v. Dora Schriro  08-99024
# 27                                   In re: Rodriguez   20-1085
# 28                                        In re: Moon   20-1057
# 29                                    In re: Morabito   19-1267
# 30                                       In re: Baham   20-1081
# 31                                      In re: Thomas   19-1331
# 32  Independent Technologies v. Otodata Wireless N...  20-15756
# 33                     City & County of S.F. v. USCIS  19-17213
# 34                      USSEC v. Dean Properties, LLC  19-17045
# 35                     Jamal Adams v. Postmates, Inc.  19-17362
# 36         Jes Solar Co., Ltd. v. Matinee Energy Inc.  19-16748
# 37               Kelvin  Hernandez Roman v. Chad Wolf  20-55436
# 38                Morgan Sanders v. City of Pittsburg  19-16920
# 39               Sergio Momox-Caselis v. Tara Donohue  19-15126
# 40                          USA v. Kevin Ruiz-Castelo  19-10034
# 41                Brigette Taylor v. Bosco Credit LLC  19-16727
# 42                              USA v. Alena Aleykina  18-10420
# 43                        USA v. Rony Asencio-De Leon  19-10118
# 44            HRC-Hainan Holding Co., LLC v. Yihan Hu  20-15371
# 45      Bristol-Myers Squibb Company v. Clare Connors  20-15515
# 46                              USA v. Gerald Delemus  19-16462
# 47                                USA v. James Lucero  19-10074
# 48               Agustin Ortega-Lopez v. William Barr  18-72441
# 49             Eduardo Velasquez-Rios v. William Barr  18-72990
#
#                                            Case Panel Hearing Location  \
# 0                  W. FLETCHER, BERZON, M. SMITH, Jr.  San Francisc...
# 1                            RAWLINSON, BENNETT, BADE      Pasadena CA
